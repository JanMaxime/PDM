# %%
import numpy as np
import cv2 as cv
from skimage.morphology import skeletonize
import glob
import tqdm
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import pandas as pd
from PIL import Image
import sknw
import networkx as nx
import random
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 10>()
#       8 import pandas as pd
#       9 from PIL import Image
# ---> 10 import sknw
#      11 import networkx as nx
#      12 import random
#
# ModuleNotFoundError: No module named 'sknw'

# %%
data = pd.read_excel("data.xlsx")

# %%
df = pd.DataFrame(columns=["year", "length"])
for a in tqdm.tqdm(glob.glob("skeletons/*.png")):
    
    #Read skeleton and transform it into a graph
    ark = a[10:-7]
    im = cv.imread(a, cv.IMREAD_GRAYSCALE).astype(np.uint16)
    year = data[data.ark == "12148_"+ark].date.values[0]
    if year != year:
        continue

    G = sknw.build_sknw(im)
    
    #Remove small segments
    deg = G.degree
    to_delete = []
    for node in G.nodes(data=True):
        if deg[node[0]] == 1:
            for neighbor in G.neighbors(node[0]):
                if np.linalg.norm(node[1]['o']-G.nodes[neighbor]['o']) < 30:
                    to_delete.append(node[0])
                    
    for node in to_delete:
        G.remove_node(node)
        
    #Add weights to the edges corresponding to the euclidean distance between the nodes                
    for (s,e) in G.edges():
        G[s][e]['weight'] = np.linalg.norm(G.nodes[e]['o']-G.nodes[s]['o'])

    number_of_paths = 0

    #Pick the 5 test points
    coords = ([2200,2200], [6000,6000], [5000,2000], [3000,6000], [4000,4000])
    target_nodes = []
    dist = 30
    for coord in coords:
        found = False
        while not found:
            for node in G.nodes(data=True):
                if np.linalg.norm(node[1]['o']-np.array(coord)) < dist:
                    target_nodes.append(node[0])
                    found = True
                    break
            if found:
                break
            dist += 20
    
    #Compute the shortest path between the 5 pairs of test points
    path_length = 0
    for src_node in target_nodes:
        for trgt_node in target_nodes:
            if src_node == trgt_node:
                continue
            try:
                path_length += nx.shortest_path_length(G, src_node, trgt_node, weight='weight')
                number_of_paths+=1
            except:
                pass
    
    if number_of_paths == 20:
        df = df.append({"radius":radius, "length":path_length/2, "year":year}, ignore_index=True)
# Out:
#   0%|                                                                                          | 0/346 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       5 ark = a[10:-7]
#       6 im = cv.imread(a, cv.IMREAD_GRAYSCALE).astype(np.uint16)
# ----> 7 year = data[data.ark == "12148_"+ark].date.values[0]
#       8 if year != year:
#       9     continue
#
# NameError: name 'data' is not defined

# %%
np.mean(path_lengths["before"])
# Out:
# 78634.98027623989

# %%
np.mean(path_lengths["after"])
# Out:
# 78982.24547983936

# %%
np.std(path_lengths["after"])
# Out:
# 3948.699872143903

# %%
temporality = ['Avant', 'Après']
x_pos = np.arange(len(temporality))
CTEs = [np.mean(path_lengths["before"]), np.mean(path_lengths["after"])]
error = [np.std(path_lengths["before"]), np.std(path_lengths["after"])]

# Build the plot
fig, ax = plt.subplots(figsize=(3,4))
ax.bar(x_pos, CTEs, yerr=error, align='center', ecolor='black', capsize=10)
ax.set_ylabel('Distance totales des 20 trajets prédéfinis')
ax.set_xticks(x_pos)
ax.set_xticklabels(temporality)
ax.set_title('')

# Save the figure and show
#plt.tight_layout()
plt.show()

# %%
# draw edges by pts
for (s,e) in G.edges():
    ps = G[s][e]['pts']
    plt.plot(ps[:,1], ps[:,0], 'green')
    

ps = np.array([G.nodes[x]['o'] for x in target_nodes])
print(ps)
plt.plot(ps[:,1], ps[:,0], 'r.')

plt.plot(5078, 4248, 'b+')
# Out:
# [[2171.33333333 2198.33333333]
#  [5819.         5877.        ]
#  [4992.         2545.        ]
#  [2472.33333333 5846.33333333]
#  [3470.         3962.        ]]
